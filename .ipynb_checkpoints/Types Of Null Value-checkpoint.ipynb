# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
data=pd.read_csv(r"C:\Users\Admin\Documents\GitHub\edu-python\dirtydata.csv")
data
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %%
data.shape
# Out:
# (32, 5)

# %%
data.dtypes
# Out:
# Duration      int64
# Date         object
# Pulse         int64
# Maxpulse      int64
# Calories    float64
# dtype: object

# %%
data.isnull().sum()
# Out:
# Duration    0
# Date        1
# Pulse       0
# Maxpulse    0
# Calories    2
# dtype: int64

# %%
#1 types of null values- "Empty cells"
#dropna & impute
data.Calories=data.Calories.fillna(data.Calories.median)

# %%
data.isnull().sum()
# Out:
# Duration    0
# Date        1
# Pulse       0
# Maxpulse    0
# Calories    0
# dtype: int64

# %%
data.dropna(inplace=True)

# %%
data.isnull().sum()
# Out:
# Duration    0
# Date        0
# Pulse       0
# Maxpulse    0
# Calories    0
# dtype: int64

# %%
#worng format data=row26 date

# %%
import datetime

# %%
data["Date"]=pd.to_datetime(data["Date"])

# %%
data
# Out:
#     Duration       Date  Pulse  Maxpulse  \
# 0         60 2020-12-01    110       130
# 1         60 2020-12-02    117       145
# 2         60 2020-12-03    103       135
# 3         45 2020-12-04    109       175
# 4         45 2020-12-05    117       148
# 5         60 2020-12-06    102       127
# 6         60 2020-12-07    110       136
# 7         45 2020-12-08    104       134
# 8         30 2020-12-09    109       133
# 9         60 2020-12-10     98       124
# 10        60 2020-12-11    103       147
# 11        60 2020-12-12    100       120
# 12        60 2020-12-12    100       120
# 13        60 2020-12-13    106       128
# 14        60 2020-12-14    104       132
# 15        60 2020-12-15     98       123
# 16        60 2020-12-16     98       120
# 17        60 2020-12-17    100       120
# 18        45 2020-12-18     90       112
# 19        60 2020-12-19    103       123
# 20        45 2020-12-20     97       125
# 21        60 2020-12-21    108       131
# ...

# %%
data.loc[7,"Duration"]=45

# %%
data
# Out:
#     Duration       Date  Pulse  Maxpulse  \
# 0         60 2020-12-01    110       130
# 1         60 2020-12-02    117       145
# 2         60 2020-12-03    103       135
# 3         45 2020-12-04    109       175
# 4         45 2020-12-05    117       148
# 5         60 2020-12-06    102       127
# 6         60 2020-12-07    110       136
# 7         45 2020-12-08    104       134
# 8         30 2020-12-09    109       133
# 9         60 2020-12-10     98       124
# 10        60 2020-12-11    103       147
# 11        60 2020-12-12    100       120
# 12        60 2020-12-12    100       120
# 13        60 2020-12-13    106       128
# 14        60 2020-12-14    104       132
# 15        60 2020-12-15     98       123
# 16        60 2020-12-16     98       120
# 17        60 2020-12-17    100       120
# 18        45 2020-12-18     90       112
# 19        60 2020-12-19    103       123
# 20        45 2020-12-20     97       125
# 21        60 2020-12-21    108       131
# ...

# %%
#4 Duplicate
data.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12     True
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# dtype: bool

# %%
data.drop_duplicates(inplace=True) #to drop duplicate row
#data

# %%
data.shape
# Out:
# (30, 5)

# %%
data.columns
# Out:
# Index(['Duration', 'Date', 'Pulse', 'Maxpulse', 'Calories'], dtype='object')

# %%
data_x=data.iloc[:,0:4]

# %%
data_x.head(2)
# Out:
#    Duration       Date  Pulse  Maxpulse
# 0        60 2020-12-01    110       130
# 1        60 2020-12-02    117       145

# %%
data_y=data.iloc[:,-1]

# %%
data_y.head(2)
# Out:
# 0    409.1
# 1    479.0
# Name: Calories, dtype: object
