# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
data=pd.read_csv(r"C:\Users\Admin\Documents\GitHub\edu-python\BreastCancer.csv")
data
# Out:
#      Unnamed: 0       Id  Cl.thickness  Cell.size  Cell.shape  Marg.adhesion  \
# 0             1  1000025             5          1           1              1
# 1             2  1002945             5          4           4              5
# 2             3  1015425             3          1           1              1
# 3             4  1016277             6          8           8              1
# 4             5  1017023             4          1           1              3
# ..          ...      ...           ...        ...         ...            ...
# 694         695   776715             3          1           1              1
# 695         696   841769             2          1           1              1
# 696         697   888820             5         10          10              3
# 697         698   897471             4          8           6              4
# 698         699   897471             4          8           8              5
#
# ...

# %%
data.shape
# Out:
# (699, 12)

# %%
data.head()
# Out:
#    Unnamed: 0       Id  Cl.thickness  Cell.size  Cell.shape  Marg.adhesion  \
# 0           1  1000025             5          1           1              1
# 1           2  1002945             5          4           4              5
# 2           3  1015425             3          1           1              1
# 3           4  1016277             6          8           8              1
# 4           5  1017023             4          1           1              3
#
#    Epith.c.size  Bare.nuclei  Bl.cromatin  Normal.nucleoli  Mitoses   Class
# 0             2          1.0            3                1        1  benign
# 1             7         10.0            3                2        1  benign
# 2             2          2.0            3                1        1  benign
# 3             3          4.0            3                7        1  benign
# 4             2          1.0            3                1        1  benign

# %%
data.tail()
# Out:
#      Unnamed: 0      Id  Cl.thickness  Cell.size  Cell.shape  Marg.adhesion  \
# 694         695  776715             3          1           1              1
# 695         696  841769             2          1           1              1
# 696         697  888820             5         10          10              3
# 697         698  897471             4          8           6              4
# 698         699  897471             4          8           8              5
#
#      Epith.c.size  Bare.nuclei  Bl.cromatin  Normal.nucleoli  Mitoses  \
# 694             3          2.0            1                1        1
# 695             2          1.0            1                1        1
# 696             7          3.0            8               10        2
# 697             3          4.0           10                6        1
# 698             4          5.0           10                4        1
#
#          Class
# 694     benign
# 695     benign
# 696  malignant
# 697  malignant
# ...

# %%
data.describe()
# Out:
#        Unnamed: 0            Id  Cl.thickness   Cell.size  Cell.shape  \
# count  699.000000  6.990000e+02    699.000000  699.000000  699.000000
# mean   350.000000  1.071704e+06      4.417740    3.134478    3.207439
# std    201.928205  6.170957e+05      2.815741    3.051459    2.971913
# min      1.000000  6.163400e+04      1.000000    1.000000    1.000000
# 25%    175.500000  8.706885e+05      2.000000    1.000000    1.000000
# 50%    350.000000  1.171710e+06      4.000000    1.000000    1.000000
# 75%    524.500000  1.238298e+06      6.000000    5.000000    5.000000
# max    699.000000  1.345435e+07     10.000000   10.000000   10.000000
#
#        Marg.adhesion  Epith.c.size  Bare.nuclei  Bl.cromatin  Normal.nucleoli  \
# count     699.000000    699.000000   683.000000   699.000000       699.000000
# mean        2.806867      3.216023     3.544656     3.437768         2.866953
# std         2.855379      2.214300     3.643857     2.438364         3.053634
# ...

# %%
data.describe(include="all")
# Out:
#         Unnamed: 0            Id  Cl.thickness   Cell.size  Cell.shape  \
# count   699.000000  6.990000e+02    699.000000  699.000000  699.000000
# unique         NaN           NaN           NaN         NaN         NaN
# top            NaN           NaN           NaN         NaN         NaN
# freq           NaN           NaN           NaN         NaN         NaN
# mean    350.000000  1.071704e+06      4.417740    3.134478    3.207439
# std     201.928205  6.170957e+05      2.815741    3.051459    2.971913
# min       1.000000  6.163400e+04      1.000000    1.000000    1.000000
# 25%     175.500000  8.706885e+05      2.000000    1.000000    1.000000
# 50%     350.000000  1.171710e+06      4.000000    1.000000    1.000000
# 75%     524.500000  1.238298e+06      6.000000    5.000000    5.000000
# max     699.000000  1.345435e+07     10.000000   10.000000   10.000000
#
#         Marg.adhesion  Epith.c.size  Bare.nuclei  Bl.cromatin  \
# ...

# %%
data.isnull().sum()
# Out:
# Unnamed: 0          0
# Id                  0
# Cl.thickness        0
# Cell.size           0
# Cell.shape          0
# Marg.adhesion       0
# Epith.c.size        0
# Bare.nuclei        16
# Bl.cromatin         0
# Normal.nucleoli     0
# Mitoses             0
# Class               0
# dtype: int64

# %%
#imutation
data["Bare.nuclei"].value_counts()
# Out:
# 1.0     402
# 10.0    132
# 2.0      30
# 5.0      30
# 3.0      28
# 8.0      21
# 4.0      19
# 9.0       9
# 7.0       8
# 6.0       4
# Name: Bare.nuclei, dtype: int64

# %%
data['Bare.nuclei']=data['Bare.nuclei'].fillna(6.0)

# %%
data['Bare.nuclei'].value_counts()
# Out:
# 1.0     402
# 10.0    132
# 2.0      30
# 5.0      30
# 3.0      28
# 8.0      21
# 6.0      20
# 4.0      19
# 9.0       9
# 7.0       8
# Name: Bare.nuclei, dtype: int64

# %%
data.isnull().sum()
# Out:
# Unnamed: 0         0
# Id                 0
# Cl.thickness       0
# Cell.size          0
# Cell.shape         0
# Marg.adhesion      0
# Epith.c.size       0
# Bare.nuclei        0
# Bl.cromatin        0
# Normal.nucleoli    0
# Mitoses            0
# Class              0
# dtype: int64

# %%
data=data.drop(['Unnamed: 0'],axis=1)

# %%
data=data.drop(['Id'],axis=1)

# %% [markdown]
# # Datatype Conversion

# %%
data.dtypes
# Out:
# Cl.thickness         int64
# Cell.size            int64
# Cell.shape           int64
# Marg.adhesion        int64
# Epith.c.size         int64
# Bare.nuclei        float64
# Bl.cromatin          int64
# Normal.nucleoli      int64
# Mitoses              int64
# Class               object
# dtype: object

# %%
data.Class.value_counts()
# Out:
# benign       458
# malignant    241
# Name: Class, dtype: int64

# %%
data.Class.replace({'benign':0,'malignant':1},inplace=True)

# %%
data.Class.value_counts()
# Out:
# 0    458
# 1    241
# Name: Class, dtype: int64

# %%
data.dtypes
# Out:
# Cl.thickness         int64
# Cell.size            int64
# Cell.shape           int64
# Marg.adhesion        int64
# Epith.c.size         int64
# Bare.nuclei        float64
# Bl.cromatin          int64
# Normal.nucleoli      int64
# Mitoses              int64
# Class                int64
# dtype: object

# %%
data_cor=data.corr()
data_cor
# Out:
#                  Cl.thickness  Cell.size  Cell.shape  Marg.adhesion  \
# Cl.thickness         1.000000   0.644913    0.654589       0.486356
# Cell.size            0.644913   1.000000    0.906882       0.705582
# Cell.shape           0.654589   0.906882    1.000000       0.683079
# Marg.adhesion        0.486356   0.705582    0.683079       1.000000
# Epith.c.size         0.521816   0.751799    0.719668       0.599599
# Bare.nuclei          0.578510   0.679704    0.704203       0.656201
# Bl.cromatin          0.558428   0.755721    0.735948       0.666715
# Normal.nucleoli      0.535835   0.722865    0.719446       0.603352
# Mitoses              0.350034   0.458693    0.438911       0.417633
# Class                0.716001   0.817904    0.818934       0.696800
#
#                  Epith.c.size  Bare.nuclei  Bl.cromatin  Normal.nucleoli  \
# Cl.thickness         0.521816     0.578510     0.558428         0.535835
# ...

# %% [markdown]
# # Visualization of dataset

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(10,9))
heatmap=sns.heatmap(data_cor,linewidth=2,annot=True,cmap=plt.cm.Blues)
plt.title("Breast Cancer")
plt.show()

# %%
#cell size and cell shape are highly corelated with independent columns(excepts mitosis)
#all independent columns have correlation between them
#Marg.adhesion low correlated with mitoses
#Epith.c.size high correlated with other columns except mitosis
#Mitosis less correlated with other columns
