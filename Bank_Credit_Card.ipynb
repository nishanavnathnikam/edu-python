# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
data1=pd.read_csv(r"C:\Users\Admin\Documents\GitHub\edu-python\BankCreditCard.csv")
data1
# Out:
#        Customer ID  Credit_Amount  Gender  Academic_Qualification  Marital  \
# 0                1        20000.0       2                       2        1
# 1                2       220000.0       2                       2        2
# 2                3        90000.0       2                       2        2
# 3                4        50000.0       2                       2        1
# 4                5        50000.0       1                       2        1
# ...            ...            ...     ...                     ...      ...
# 29995        29996       220000.0       1                       3        1
# 29996        29997       250000.0       1                       3        2
# 29997        29998        30000.0       1                       2        2
# 29998        29999        80000.0       1                       3        1
# 29999        30000        50000.0       1                       2        1
#
#        Age_Years  Repayment_Status_Jan  Repayment_Status_Feb  \
# ...

# %%
data1.shape  #details in number of rows and columns in data frame
# Out:
# (30000, 25)

# %%
data1.head() #used to display the first few rows
# Out:
#    Customer ID  Credit_Amount  Gender  Academic_Qualification  Marital  \
# 0            1        20000.0       2                       2        1
# 1            2       220000.0       2                       2        2
# 2            3        90000.0       2                       2        2
# 3            4        50000.0       2                       2        1
# 4            5        50000.0       1                       2        1
#
#    Age_Years  Repayment_Status_Jan  Repayment_Status_Feb  \
# 0         24                     2                     2
# 1         26                     0                     2
# 2         34                     0                     0
# 3         37                     0                     0
# 4         57                     0                     0
#
#    Repayment_Status_March  Repayment_Status_April  ...  April_Bill_Amount  \
# 0                       0                       0  ...                0.0
# ...

# %%
data1.tail()#by default last 5 rows
# Out:
#        Customer ID  Credit_Amount  Gender  Academic_Qualification  Marital  \
# 29995        29996       220000.0       1                       3        1
# 29996        29997       250000.0       1                       3        2
# 29997        29998        30000.0       1                       2        2
# 29998        29999        80000.0       1                       3        1
# 29999        30000        50000.0       1                       2        1
#
#        Age_Years  Repayment_Status_Jan  Repayment_Status_Feb  \
# 29995         39                     0                     0
# 29996         43                     0                     0
# 29997         37                     4                     3
# 29998         41                     1                     0
# 29999         46                     0                     0
#
#        Repayment_Status_March  Repayment_Status_April  ...  April_Bill_Amount  \
# ...

# %%
data1=data1.drop(["Customer ID"],axis=1)
data1
# Out:
#        Credit_Amount  Gender  Academic_Qualification  Marital  Age_Years  \
# 0            20000.0       2                       2        1         24
# 1           220000.0       2                       2        2         26
# 2            90000.0       2                       2        2         34
# 3            50000.0       2                       2        1         37
# 4            50000.0       1                       2        1         57
# ...              ...     ...                     ...      ...        ...
# 29995       220000.0       1                       3        1         39
# 29996       250000.0       1                       3        2         43
# 29997        30000.0       1                       2        2         37
# 29998        80000.0       1                       3        1         41
# 29999        50000.0       1                       2        1         46
#
#        Repayment_Status_Jan  Repayment_Status_Feb  Repayment_Status_March  \
# ...

# %%
data1.describe()
# Out:
#        Credit_Amount        Gender  Academic_Qualification       Marital  \
# count   3.000000e+04  30000.000000            30000.000000  30000.000000
# mean    1.929173e+05      1.603733                1.855933      1.551867
# std     1.322888e+05      0.489129                0.794397      0.521970
# min     2.000000e+04      1.000000                1.000000      0.000000
# 25%     5.000000e+04      1.000000                1.000000      1.000000
# 50%     2.200000e+05      2.000000                2.000000      2.000000
# 75%     2.700000e+05      2.000000                2.000000      2.000000
# max     2.000000e+06      2.000000                6.000000      3.000000
#
#           Age_Years  Repayment_Status_Jan  Repayment_Status_Feb  \
# count  30000.000000          30000.000000          30000.000000
# mean      35.485500              0.355200              0.319300
# std        9.217904              0.746984              0.796012
# ...

# %% [markdown]
# # Cleaning the data(preprocessing)

# %%
data1.isnull().sum()
# Out:
# Credit_Amount             0
# Gender                    0
# Academic_Qualification    0
# Marital                   0
# Age_Years                 0
# Repayment_Status_Jan      0
# Repayment_Status_Feb      0
# Repayment_Status_March    0
# Repayment_Status_April    0
# Repayment_Status_May      0
# Repayment_Status_June     0
# Jan_Bill_Amount           0
# Feb_Bill_Amount           0
# March_Bill_Amount         0
# April_Bill_Amount         0
# May_Bill_Amount           0
# June_Bill_Amount          0
# Previous_Payment_Jan      0
# Previous_Payment_Feb      0
# Previous_Payment_March    0
# Previous_Payment_April    0
# Previous_Payment_May      0
# Previous_Payment_June     0
# Default_Payment           0
# dtype: int64

# %% [markdown]
# # Data-type Conversion

# %%
data1.dtypes
# Out:
# Credit_Amount             float64
# Gender                      int64
# Academic_Qualification      int64
# Marital                     int64
# Age_Years                   int64
# Repayment_Status_Jan        int64
# Repayment_Status_Feb        int64
# Repayment_Status_March      int64
# Repayment_Status_April      int64
# Repayment_Status_May        int64
# Repayment_Status_June       int64
# Jan_Bill_Amount           float64
# Feb_Bill_Amount           float64
# March_Bill_Amount         float64
# April_Bill_Amount         float64
# May_Bill_Amount           float64
# June_Bill_Amount          float64
# Previous_Payment_Jan      float64
# Previous_Payment_Feb      float64
# Previous_Payment_March    float64
# Previous_Payment_April    float64
# Previous_Payment_May      float64
# Previous_Payment_June     float64
# Default_Payment             int64
# dtype: object

# %%
data1_cor=data1.corr()
data1_cor
# Out:
#                         Credit_Amount    Gender  Academic_Qualification  \
# Credit_Amount                1.000000  0.039800               -0.213506
# Gender                       0.039800  1.000000                0.012897
# Academic_Qualification      -0.213506  0.012897                1.000000
# Marital                     -0.104797 -0.031389               -0.141637
# Age_Years                    0.135357 -0.090874                0.175458
# Repayment_Status_Jan        -0.174325 -0.034521                0.049837
# Repayment_Status_Feb        -0.200720 -0.044876                0.054034
# Repayment_Status_March      -0.196130 -0.041174                0.044626
# Repayment_Status_April      -0.185646 -0.039701                0.043856
# Repayment_Status_May        -0.173779 -0.038613                0.032593
# Repayment_Status_June       -0.168446 -0.032042                0.021863
# Jan_Bill_Amount              0.287284 -0.028792                0.022945
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(20,10))
heatmap=sns.heatmap(data1_cor,linewidth=2,annot=True,cmap=plt.cm.Blues)
plt.title("Bank_Credit_Card")
plt.show()

# %%
data1.dtypes
# Out:
# Credit_Amount             float64
# Gender                      int64
# Academic_Qualification      int64
# Marital                     int64
# Age_Years                   int64
# Repayment_Status_Jan        int64
# Repayment_Status_Feb        int64
# Repayment_Status_March      int64
# Repayment_Status_April      int64
# Repayment_Status_May        int64
# Repayment_Status_June       int64
# Jan_Bill_Amount           float64
# Feb_Bill_Amount           float64
# March_Bill_Amount         float64
# April_Bill_Amount         float64
# May_Bill_Amount           float64
# June_Bill_Amount          float64
# Previous_Payment_Jan      float64
# Previous_Payment_Feb      float64
# Previous_Payment_March    float64
# Previous_Payment_April    float64
# Previous_Payment_May      float64
# Previous_Payment_June     float64
# Default_Payment             int64
# dtype: object

# %%
data1.skew()
# Out:
# Credit_Amount              0.515894
# Gender                    -0.424183
# Academic_Qualification     1.017944
# Marital                   -0.018742
# Age_Years                  0.732246
# Repayment_Status_Jan       2.485379
# Repayment_Status_Feb       2.488460
# Repayment_Status_March     2.684191
# Repayment_Status_April     3.213051
# Repayment_Status_May       3.589727
# Repayment_Status_June      3.495517
# Jan_Bill_Amount            1.768960
# Feb_Bill_Amount            2.771193
# March_Bill_Amount          2.788757
# April_Bill_Amount          2.131962
# May_Bill_Amount            2.879272
# June_Bill_Amount           2.840817
# Previous_Payment_Jan      15.279685
# Previous_Payment_Feb      41.802935
# Previous_Payment_March    19.012134
# Previous_Payment_April    13.299057
# Previous_Payment_May      12.231259
# Previous_Payment_June     10.640727
# Default_Payment            1.343504
# dtype: float64

# %%
data1.boxplot()
# Out:
# <AxesSubplot:>

# %%
fig=plt.figure(figsize=(5,5))
sns.boxplot(data=data1,y="Credit_Amount")
# Out:
# <AxesSubplot:ylabel='Credit_Amount'>

# %%
data1.Credit_Amount.hist()
# Out:
# <AxesSubplot:>

# %%
sns.distplot(data1.Credit_Amount)
# Out:
# <AxesSubplot:xlabel='Credit_Amount', ylabel='Density'>

# %%
data1.Credit_Amount.describe()
# Out:
# count    3.000000e+04
# mean     1.929173e+05
# std      1.322888e+05
# min      2.000000e+04
# 25%      5.000000e+04
# 50%      2.200000e+05
# 75%      2.700000e+05
# max      2.000000e+06
# Name: Credit_Amount, dtype: float64

# %%
IQR1=data1.Credit_Amount.quantile(0.75)-data1.Credit_Amount.quantile(0.25)
IQR1
# Out:
# 220000.0

# %%
ub1=data1.Credit_Amount.quantile(0.75)+3*IQR1
lb1=data1.Credit_Amount.quantile(0.25)-3*IQR1
print(ub1,lb1)
# Out:
# 930000.0 -610000.0

# %%
data1.loc[data1["Credit_Amount"]>930000,"Credit_Amount"]=930000

# %%
sns.distplot(data1.Credit_Amount)
# Out:
# <AxesSubplot:xlabel='Credit_Amount', ylabel='Density'>

# %%
data1.Credit_Amount.hist()
# Out:
# <AxesSubplot:>

# %%
data1.skew()
# Out:
# Credit_Amount              0.440916
# Gender                    -0.424183
# Academic_Qualification     1.017944
# Marital                   -0.018742
# Age_Years                  0.732246
# Repayment_Status_Jan       2.485379
# Repayment_Status_Feb       2.488460
# Repayment_Status_March     2.684191
# Repayment_Status_April     3.213051
# Repayment_Status_May       3.589727
# Repayment_Status_June      3.495517
# Jan_Bill_Amount            1.768960
# Feb_Bill_Amount            2.771193
# March_Bill_Amount          2.788757
# April_Bill_Amount          2.131962
# May_Bill_Amount            2.879272
# June_Bill_Amount           2.840817
# Previous_Payment_Jan      15.279685
# Previous_Payment_Feb      41.802935
# Previous_Payment_March    19.012134
# Previous_Payment_April    13.299057
# Previous_Payment_May      12.231259
# Previous_Payment_June     10.640727
# Default_Payment            1.343504
# dtype: float64

# %%
fig=plt.figure(figsize=(5,5))
sns.boxplot(data=data1,y="Age_Years")
# Out:
# <AxesSubplot:ylabel='Age_Years'>

# %%
sns.distplot(data1.Age_Years)
# Out:
# <AxesSubplot:xlabel='Age_Years', ylabel='Density'>

# %%
data1.Age_Years.hist()
# Out:
# <AxesSubplot:>

# %%
data1.Age_Years.describe()
# Out:
# count    30000.000000
# mean        35.485500
# std          9.217904
# min         21.000000
# 25%         28.000000
# 50%         34.000000
# 75%         41.000000
# max         79.000000
# Name: Age_Years, dtype: float64

# %%
IQR2=data1.Age_Years.quantile(0.75)-data1.Age_Years.quantile(0.25)
IQR2
# Out:
# 13.0

# %%
ub1=data1.Age_Years.quantile(0.75)+3*IQR2
lb1=data1.Age_Years.quantile(0.25)-3*IQR2
print(ub1,lb1)
# Out:
# 80.0 -11.0

# %%
data1.loc[data1["Age_Years"]>80,"Age_Years"]=80

# %%
sns.distplot(data1.Age_Years)
# Out:
# <AxesSubplot:xlabel='Age_Years', ylabel='Density'>

# %%
data1.Age_Years.hist()
# Out:
# <AxesSubplot:>

# %%
data1.skew()
# Out:
# Credit_Amount              0.440916
# Gender                    -0.424183
# Academic_Qualification     1.017944
# Marital                   -0.018742
# Age_Years                  0.732246
# Repayment_Status_Jan       2.485379
# Repayment_Status_Feb       2.488460
# Repayment_Status_March     2.684191
# Repayment_Status_April     3.213051
# Repayment_Status_May       3.589727
# Repayment_Status_June      3.495517
# Jan_Bill_Amount            1.768960
# Feb_Bill_Amount            2.771193
# March_Bill_Amount          2.788757
# April_Bill_Amount          2.131962
# May_Bill_Amount            2.879272
# June_Bill_Amount           2.840817
# Previous_Payment_Jan      15.279685
# Previous_Payment_Feb      41.802935
# Previous_Payment_March    19.012134
# Previous_Payment_April    13.299057
# Previous_Payment_May      12.231259
# Previous_Payment_June     10.640727
# Default_Payment            1.343504
# dtype: float64

# %%
fig=plt.figure(figsize=(5,5))
sns.boxplot(data=data1,y="Jan_Bill_Amount")
# Out:
# <AxesSubplot:ylabel='Jan_Bill_Amount'>

# %%
sns.distplot(data1.Jan_Bill_Amount)
# Out:
# <AxesSubplot:xlabel='Jan_Bill_Amount', ylabel='Density'>

# %%
data1.Jan_Bill_Amount.hist()
# Out:
# <AxesSubplot:>

# %%
data1.Jan_Bill_Amount.describe()
# Out:
# count     30000.000000
# mean      81581.060100
# std      123026.372701
# min     -365580.000000
# 25%        3890.000000
# 50%       35661.500000
# 75%       67091.000000
# max      964533.000000
# Name: Jan_Bill_Amount, dtype: float64

# %%
IQR3=data1.Jan_Bill_Amount.quantile(0.75)-data1.Jan_Bill_Amount.quantile(0.25)
IQR3
# Out:
# 63201.0

# %%
ub1=data1.Jan_Bill_Amount.quantile(0.75)+3*IQR3
lb1=data1.Jan_Bill_Amount.quantile(0.25)-3*IQR3
print(ub1,lb1)
# Out:
# 256694.0 -185713.0

# %%
data1.loc[data1["Jan_Bill_Amount"]>256694.0,"Jan_Bill_Amount"]=256694.0
data1.loc[data1["Jan_Bill_Amount"]<-185713.0,"Jan_Bill_Amount"]=-185713.0

# %%
sns.distplot(data1.Jan_Bill_Amount)
# Out:
# <AxesSubplot:xlabel='Jan_Bill_Amount', ylabel='Density'>

# %%
data1.Jan_Bill_Amount.hist()
# Out:
# <AxesSubplot:>

# %%
data1.skew()
# Out:
# Credit_Amount              0.440916
# Gender                    -0.424183
# Academic_Qualification     1.017944
# Marital                   -0.018742
# Age_Years                  0.732246
# Repayment_Status_Jan       2.485379
# Repayment_Status_Feb       2.488460
# Repayment_Status_March     2.684191
# Repayment_Status_April     3.213051
# Repayment_Status_May       3.589727
# Repayment_Status_June      3.495517
# Jan_Bill_Amount            1.527639
# Feb_Bill_Amount            2.771193
# March_Bill_Amount          2.788757
# April_Bill_Amount          2.131962
# May_Bill_Amount            2.879272
# June_Bill_Amount           2.840817
# Previous_Payment_Jan      15.279685
# Previous_Payment_Feb      41.802935
# Previous_Payment_March    19.012134
# Previous_Payment_April    13.299057
# Previous_Payment_May      12.231259
# Previous_Payment_June     10.640727
# Default_Payment            1.343504
# dtype: float64

# %% [markdown]
# # Feb_Bill_Amount

# %%
sns.boxplot(data=data1,y="Feb_Bill_Amount")
# Out:
# <AxesSubplot:ylabel='Feb_Bill_Amount'>

# %%
sns.distplot(data1.Feb_Bill_Amount)
# Out:
# <AxesSubplot:xlabel='Feb_Bill_Amount', ylabel='Density'>

# %%
data1.Feb_Bill_Amount.hist()
# Out:
# <AxesSubplot:>

# %%
data1.Feb_Bill_Amount.describe()
# Out:
# count     30000.000000
# mean      52517.103000
# std       80401.365192
# min      -58777.000000
# 25%        3517.000000
# 50%       30538.000000
# 75%       57420.500000
# max      883831.000000
# Name: Feb_Bill_Amount, dtype: float64

# %%
IQR4=data1.Feb_Bill_Amount.quantile(0.75)-data1.Feb_Bill_Amount.quantile(0.25)
IQR4
# Out:
# 53903.5

# %%
ub4=data1.Feb_Bill_Amount.quantile(0.75)+3*IQR4
lb4=data1.Feb_Bill_Amount.quantile(0.25)-3*IQR4
print(ub4,lb4)
# Out:
# 219131.0 -158193.5

# %%
data1.loc[data1["Feb_Bill_Amount"]>219131.0,"Feb_Bill_Amount"]=219131.0

# %%
sns.distplot(data1.Feb_Bill_Amount)
# Out:
# <AxesSubplot:xlabel='Feb_Bill_Amount', ylabel='Density'>

# %%
data1.Feb_Bill_Amount.hist()
# Out:
# <AxesSubplot:>

# %%
data1.skew()
# Out:
# Credit_Amount              0.440916
# Gender                    -0.424183
# Academic_Qualification     1.017944
# Marital                   -0.018742
# Age_Years                  0.732246
# Repayment_Status_Jan       2.485379
# Repayment_Status_Feb       2.488460
# Repayment_Status_March     2.684191
# Repayment_Status_April     3.213051
# Repayment_Status_May       3.589727
# Repayment_Status_June      3.495517
# Jan_Bill_Amount            1.527639
# Feb_Bill_Amount            1.632576
# March_Bill_Amount          2.788757
# April_Bill_Amount          2.131962
# May_Bill_Amount            2.879272
# June_Bill_Amount           2.840817
# Previous_Payment_Jan      15.279685
# Previous_Payment_Feb      41.802935
# Previous_Payment_March    19.012134
# Previous_Payment_April    13.299057
# Previous_Payment_May      12.231259
# Previous_Payment_June     10.640727
# Default_Payment            1.343504
# dtype: float64

# %%
sns.boxplot(data=data1,y="March_Bill_Amount")
# Out:
# <AxesSubplot:ylabel='March_Bill_Amount'>

# %%
sns.distplot(data1.March_Bill_Amount)
# Out:
# <AxesSubplot:xlabel='March_Bill_Amount', ylabel='Density'>

# %%
data1.March_Bill_Amount.hist()
# Out:
# <AxesSubplot:>

# %%
data1.March_Bill_Amount.describe()
# Out:
# count    3.000000e+04
# mean     5.900389e+04
# std      8.841747e+04
# min     -2.572640e+05
# 25%      2.876000e+03
# 50%      2.656800e+04
# 75%      6.025250e+04
# max      2.664089e+06
# Name: March_Bill_Amount, dtype: float64

# %%
IQR5=data1.March_Bill_Amount.quantile(0.75)-data1.March_Bill_Amount.quantile(0.25)
IQR5
# Out:
# 57376.5

# %%
ub5=data1.March_Bill_Amount.quantile(0.75)+3*IQR5
lb5=data1.March_Bill_Amount.quantile(0.25)-3*IQR5
print(ub5,lb5)
# Out:
# 232382.0 -169253.5

# %%
data1.loc[data1["March_Bill_Amount"]>232382.0,"March_Bill_Amount"]=232382.0
data1.loc[data1["March_Bill_Amount"]<-169253.5,"March_Bill_Amount"]=-169253.5

# %%
sns.distplot(data1.March_Bill_Amount)
# Out:
# <AxesSubplot:xlabel='March_Bill_Amount', ylabel='Density'>

# %%
data1.March_Bill_Amount.hist()
# Out:
# <AxesSubplot:>

# %%
data1.skew()
# Out:
# Credit_Amount              0.440916
# Gender                    -0.424183
# Academic_Qualification     1.017944
# Marital                   -0.018742
# Age_Years                  0.732246
# Repayment_Status_Jan       2.485379
# Repayment_Status_Feb       2.488460
# Repayment_Status_March     2.684191
# Repayment_Status_April     3.213051
# Repayment_Status_May       3.589727
# Repayment_Status_June      3.495517
# Jan_Bill_Amount            1.527639
# Feb_Bill_Amount            1.632576
# March_Bill_Amount          1.626987
# April_Bill_Amount          2.131962
# May_Bill_Amount            2.879272
# June_Bill_Amount           2.840817
# Previous_Payment_Jan      15.279685
# Previous_Payment_Feb      41.802935
# Previous_Payment_March    19.012134
# Previous_Payment_April    13.299057
# Previous_Payment_May      12.231259
# Previous_Payment_June     10.640727
# Default_Payment            1.343504
# dtype: float64

# %%
sns.boxplot(data=data1,y="April_Bill_Amount")
# Out:
# <AxesSubplot:ylabel='April_Bill_Amount'>

# %%
sns.distplot(data1.April_Bill_Amount)
# Out:
# <AxesSubplot:xlabel='April_Bill_Amount', ylabel='Density'>

# %%
data1.April_Bill_Amount.hist()
# Out:
# <AxesSubplot:>

# %%
data1.April_Bill_Amount.describe()
# Out:
# count     30000.000000
# mean      55122.263933
# std       83577.329356
# min     -270000.000000
# 25%        2671.500000
# 50%       25629.000000
# 75%       54508.500000
# max      992596.000000
# Name: April_Bill_Amount, dtype: float64

# %%
IQR6=data1.April_Bill_Amount.quantile(0.75)-data1.April_Bill_Amount.quantile(0.25)
IQR6
# Out:
# 51837.0

# %%
ub6=data1.April_Bill_Amount.quantile(0.75)+3*IQR6
lb6=data1.April_Bill_Amount.quantile(0.25)-3*IQR6
print(ub6,lb6)
# Out:
# 210019.5 -152839.5

# %%
data1.loc[data1["April_Bill_Amount"]>210019.5,"April_Bill_Amount"]=210019.5
data1.loc[data1["April_Bill_Amount"]<-152839.5,"April_Bill_Amount"]=-152839.5

# %%
sns.distplot(data1.April_Bill_Amount)
# Out:
# <AxesSubplot:xlabel='April_Bill_Amount', ylabel='Density'>

# %%
data1.April_Bill_Amount.hist()
# Out:
# <AxesSubplot:>

# %%
data1.skew()
# Out:
# Credit_Amount              0.440916
# Gender                    -0.424183
# Academic_Qualification     1.017944
# Marital                   -0.018742
# Age_Years                  0.732246
# Repayment_Status_Jan       2.485379
# Repayment_Status_Feb       2.488460
# Repayment_Status_March     2.684191
# Repayment_Status_April     3.213051
# Repayment_Status_May       3.589727
# Repayment_Status_June      3.495517
# Jan_Bill_Amount            1.527639
# Feb_Bill_Amount            1.632576
# March_Bill_Amount          1.626987
# April_Bill_Amount          1.669499
# May_Bill_Amount            2.879272
# June_Bill_Amount           2.840817
# Previous_Payment_Jan      15.279685
# Previous_Payment_Feb      41.802935
# Previous_Payment_March    19.012134
# Previous_Payment_April    13.299057
# Previous_Payment_May      12.231259
# Previous_Payment_June     10.640727
# Default_Payment            1.343504
# dtype: float64

# %%
sns.boxplot(data=data1,y="May_Bill_Amount")
# Out:
# <AxesSubplot:ylabel='May_Bill_Amount'>

# %%
sns.distplot(data1.May_Bill_Amount)
# Out:
# <AxesSubplot:xlabel='May_Bill_Amount', ylabel='Density'>

# %%
data1.May_Bill_Amount.hist()
# Out:
# <AxesSubplot:>

# %%
data1.May_Bill_Amount.describe()
# Out:
# count     30000.000000
# mean      39939.618800
# std       60373.934792
# min      -81334.000000
# 25%        1763.000000
# 50%       18043.000000
# 75%       50190.500000
# max      827171.000000
# Name: May_Bill_Amount, dtype: float64

# %%
IQR7=data1.May_Bill_Amount.quantile(0.75)-data1.May_Bill_Amount.quantile(0.25)
IQR7
# Out:
# 48427.5

# %%
ub7=data1.May_Bill_Amount.quantile(0.75)+3*IQR7
lb7=data1.May_Bill_Amount.quantile(0.25)-3*IQR7
print(ub7,lb7)
# Out:
# 195473.0 -143519.5

# %%
data1.loc[data1["May_Bill_Amount"]>195473.0,"May_Bill_Amount"]=195473.0
data1.loc[data1["May_Bill_Amount"]< -143519.5,"May_Bill_Amount"]=-143519.50

# %%
sns.distplot(data1.May_Bill_Amount)
# Out:
# <AxesSubplot:xlabel='May_Bill_Amount', ylabel='Density'>

# %%
data1.May_Bill_Amount.hist()
# Out:
# <AxesSubplot:>

# %%
data1.skew()
# Out:
# Credit_Amount              0.440916
# Gender                    -0.424183
# Academic_Qualification     1.017944
# Marital                   -0.018742
# Age_Years                  0.732246
# Repayment_Status_Jan       2.485379
# Repayment_Status_Feb       2.488460
# Repayment_Status_March     2.684191
# Repayment_Status_April     3.213051
# Repayment_Status_May       3.589727
# Repayment_Status_June      3.495517
# Jan_Bill_Amount            1.527639
# Feb_Bill_Amount            1.632576
# March_Bill_Amount          1.626987
# April_Bill_Amount          1.669499
# May_Bill_Amount            1.749921
# June_Bill_Amount           2.840817
# Previous_Payment_Jan      15.279685
# Previous_Payment_Feb      41.802935
# Previous_Payment_March    19.012134
# Previous_Payment_April    13.299057
# Previous_Payment_May      12.231259
# Previous_Payment_June     10.640727
# Default_Payment            1.343504
# dtype: float64

# %%
sns.boxplot(data=data1,y="June_Bill_Amount")
# Out:
# <AxesSubplot:ylabel='June_Bill_Amount'>

# %%
sns.distplot(data1.June_Bill_Amount)
# Out:
# <AxesSubplot:xlabel='June_Bill_Amount', ylabel='Density'>

# %%
data1.June_Bill_Amount.hist()
# Out:
# <AxesSubplot:>

# %%
data1.June_Bill_Amount.describe()
# Out:
# count     30000.000000
# mean      38506.051533
# std       59104.280171
# min     -338603.000000
# 25%        1256.000000
# 50%       17071.000000
# 75%       48655.250000
# max      861664.000000
# Name: June_Bill_Amount, dtype: float64

# %%
IQR8=data1.June_Bill_Amount.quantile(0.75)-data1.June_Bill_Amount.quantile(0.25)
IQR8
# Out:
# 47399.25

# %%
ub8=data1.June_Bill_Amount.quantile(0.75)+3*IQR8
lb8=data1.June_Bill_Amount.quantile(0.25)-3*IQR8
print(ub8,lb8)
# Out:
# 190853.0 -140941.75

# %%
data1.loc[data1["June_Bill_Amount"]>190853.0,"June_Bill_Amount"]=190853.0
data1.loc[data1["June_Bill_Amount"]< -140941,"June_Bill_Amount"]= -140941

# %%
sns.distplot(data1.June_Bill_Amount)
# Out:
# <AxesSubplot:xlabel='June_Bill_Amount', ylabel='Density'>

# %%
data1.June_Bill_Amount.hist()
# Out:
# <AxesSubplot:>

# %%
data1.skew()
# Out:
# Credit_Amount              0.440916
# Gender                    -0.424183
# Academic_Qualification     1.017944
# Marital                   -0.018742
# Age_Years                  0.732246
# Repayment_Status_Jan       2.485379
# Repayment_Status_Feb       2.488460
# Repayment_Status_March     2.684191
# Repayment_Status_April     3.213051
# Repayment_Status_May       3.589727
# Repayment_Status_June      3.495517
# Jan_Bill_Amount            1.527639
# Feb_Bill_Amount            1.632576
# March_Bill_Amount          1.626987
# April_Bill_Amount          1.669499
# May_Bill_Amount            1.749921
# June_Bill_Amount           1.749088
# Previous_Payment_Jan      15.279685
# Previous_Payment_Feb      41.802935
# Previous_Payment_March    19.012134
# Previous_Payment_April    13.299057
# Previous_Payment_May      12.231259
# Previous_Payment_June     10.640727
# Default_Payment            1.343504
# dtype: float64

# %%
sns.boxplot(data=data1,y="Previous_Payment_Jan")
# Out:
# <AxesSubplot:ylabel='Previous_Payment_Jan'>

# %%
sns.distplot(data1.Previous_Payment_Jan)
# Out:
# <AxesSubplot:xlabel='Previous_Payment_Jan', ylabel='Density'>

# %%
data1.Previous_Payment_Jan.hist()
# Out:
# <AxesSubplot:>

# %%
data1.Previous_Payment_Jan.describe()
# Out:
# count     30000.000000
# mean       6285.653867
# std       18944.920299
# min           0.000000
# 25%        1000.000000
# 50%        3000.000000
# 75%        6000.000000
# max      973663.000000
# Name: Previous_Payment_Jan, dtype: float64

# %%
IQR9=data1.Previous_Payment_Jan.quantile(0.75)-data1.Previous_Payment_Jan.quantile(0.25)
IQR9
# Out:
# 5000.0

# %%
ub9=data1.Previous_Payment_Jan.quantile(0.75)+3*IQR9
lb9=data1.Previous_Payment_Jan.quantile(0.25)-3*IQR9
print(ub9,lb9)
# Out:
# 21000.0 -14000.0

# %%
data1.loc[data1["Previous_Payment_Jan"]>21000.0,"Previous_Payment_Jan"]=21000.0

# %%
sns.distplot(data1.Previous_Payment_Jan)
# Out:
# <AxesSubplot:xlabel='Previous_Payment_Jan', ylabel='Density'>

# %%
data1.Previous_Payment_Jan.hist()
# Out:
# <AxesSubplot:>

# %%
data1.skew()
# Out:
# Credit_Amount              0.440916
# Gender                    -0.424183
# Academic_Qualification     1.017944
# Marital                   -0.018742
# Age_Years                  0.732246
# Repayment_Status_Jan       2.485379
# Repayment_Status_Feb       2.488460
# Repayment_Status_March     2.684191
# Repayment_Status_April     3.213051
# Repayment_Status_May       3.589727
# Repayment_Status_June      3.495517
# Jan_Bill_Amount            1.527639
# Feb_Bill_Amount            1.632576
# March_Bill_Amount          1.626987
# April_Bill_Amount          1.669499
# May_Bill_Amount            1.749921
# June_Bill_Amount           1.749088
# Previous_Payment_Jan       1.878646
# Previous_Payment_Feb      41.802935
# Previous_Payment_March    19.012134
# Previous_Payment_April    13.299057
# Previous_Payment_May      12.231259
# Previous_Payment_June     10.640727
# Default_Payment            1.343504
# dtype: float64

# %%
sns.boxplot(data=data1,y="Previous_Payment_Feb")
# Out:
# <AxesSubplot:ylabel='Previous_Payment_Feb'>

# %%
sns.distplot(data1.Previous_Payment_Feb)
# Out:
# <AxesSubplot:xlabel='Previous_Payment_Feb', ylabel='Density'>

# %%
data1.Previous_Payment_Feb.hist()
# Out:
# <AxesSubplot:>

# %%
data1.Previous_Payment_Feb.describe()
# Out:
# count    3.000000e+04
# mean     7.466544e+03
# std      3.467950e+04
# min      0.000000e+00
# 25%      7.700000e+02
# 50%      2.542000e+03
# 75%      5.000000e+03
# max      2.674259e+06
# Name: Previous_Payment_Feb, dtype: float64

# %%
IQR10=data1.Previous_Payment_Feb.quantile(0.75)-data1.Previous_Payment_Feb.quantile(0.25)
IQR10
# Out:
# 4230.0

# %%
ub10=data1.Previous_Payment_Feb.quantile(0.75)+3*IQR10
lb10=data1.Previous_Payment_Feb.quantile(0.25)-3*IQR10
print(ub10,lb10)
# Out:
# 17690.0 -11920.0

# %%
data1.loc[data1["Previous_Payment_Feb"]>17690.0,"Previous_Payment_Feb"]=17690.0

# %%
sns.distplot(data1.Previous_Payment_Feb)
# Out:
# <AxesSubplot:xlabel='Previous_Payment_Feb', ylabel='Density'>

# %%
data1.Previous_Payment_Feb.hist()
# Out:
# <AxesSubplot:>

# %%
data1.skew()
# Out:
# Credit_Amount              0.440916
# Gender                    -0.424183
# Academic_Qualification     1.017944
# Marital                   -0.018742
# Age_Years                  0.732246
# Repayment_Status_Jan       2.485379
# Repayment_Status_Feb       2.488460
# Repayment_Status_March     2.684191
# Repayment_Status_April     3.213051
# Repayment_Status_May       3.589727
# Repayment_Status_June      3.495517
# Jan_Bill_Amount            1.527639
# Feb_Bill_Amount            1.632576
# March_Bill_Amount          1.626987
# April_Bill_Amount          1.669499
# May_Bill_Amount            1.749921
# June_Bill_Amount           1.749088
# Previous_Payment_Jan       1.878646
# Previous_Payment_Feb       1.741080
# Previous_Payment_March    19.012134
# Previous_Payment_April    13.299057
# Previous_Payment_May      12.231259
# Previous_Payment_June     10.640727
# Default_Payment            1.343504
# dtype: float64

# %%
sns.boxplot(data=data1,y="Previous_Payment_March")
# Out:
# <AxesSubplot:ylabel='Previous_Payment_March'>

# %%
sns.distplot(data1.Previous_Payment_March)
# Out:
# <AxesSubplot:xlabel='Previous_Payment_March', ylabel='Density'>

# %%
data1.Previous_Payment_March.hist()
# Out:
# <AxesSubplot:>

# %%
data1.Previous_Payment_March.describe()
# Out:
# count     30000.000000
# mean       5836.140567
# std       20696.306703
# min           0.000000
# 25%         550.000000
# 50%        1900.000000
# 75%        5500.000000
# max      999055.000000
# Name: Previous_Payment_March, dtype: float64

# %%
IQR11=data1.Previous_Payment_March.quantile(0.75)-data1.Previous_Payment_March.quantile(0.25)
IQR11
# Out:
# 4950.0

# %%
ub11=data1.Previous_Payment_March.quantile(0.75)+3*IQR11
lb11=data1.Previous_Payment_March.quantile(0.25)-3*IQR11
print(ub11,lb11)
# Out:
# 20350.0 -14300.0

# %%
data1.loc[data1["Previous_Payment_March"]>20350.0,"Previous_Payment_March"]=20350.0

# %%
sns.distplot(data1.Previous_Payment_March)
# Out:
# <AxesSubplot:xlabel='Previous_Payment_March', ylabel='Density'>

# %%
data1.Previous_Payment_March.hist()
# Out:
# <AxesSubplot:>

# %%
data1.skew()
# Out:
# Credit_Amount              0.440916
# Gender                    -0.424183
# Academic_Qualification     1.017944
# Marital                   -0.018742
# Age_Years                  0.732246
# Repayment_Status_Jan       2.485379
# Repayment_Status_Feb       2.488460
# Repayment_Status_March     2.684191
# Repayment_Status_April     3.213051
# Repayment_Status_May       3.589727
# Repayment_Status_June      3.495517
# Jan_Bill_Amount            1.527639
# Feb_Bill_Amount            1.632576
# March_Bill_Amount          1.626987
# April_Bill_Amount          1.669499
# May_Bill_Amount            1.749921
# June_Bill_Amount           1.749088
# Previous_Payment_Jan       1.878646
# Previous_Payment_Feb       1.741080
# Previous_Payment_March     1.949059
# Previous_Payment_April    13.299057
# Previous_Payment_May      12.231259
# Previous_Payment_June     10.640727
# Default_Payment            1.343504
# dtype: float64

# %%
sns.boxplot(data=data1,y="Previous_Payment_April")
# Out:
# <AxesSubplot:ylabel='Previous_Payment_April'>

# %%
sns.distplot(data1.Previous_Payment_April)
# Out:
# <AxesSubplot:xlabel='Previous_Payment_April', ylabel='Density'>

# %%
data1.Previous_Payment_April.hist()
# Out:
# <AxesSubplot:>

# %%
data1.Previous_Payment_April.describe()
# Out:
# count     30000.000000
# mean       5127.687433
# std       17103.762740
# min           0.000000
# 25%         333.000000
# 50%        1500.000000
# 75%        4013.250000
# max      538897.000000
# Name: Previous_Payment_April, dtype: float64

# %%
IQR12=data1.Previous_Payment_April.quantile(0.75)-data1.Previous_Payment_April.quantile(0.25)
IQR12
# Out:
# 3680.25

# %%
ub12=data1.Previous_Payment_April.quantile(0.75)+3*IQR12
lb12=data1.Previous_Payment_April.quantile(0.25)-3*IQR12
print(ub12,lb12)
# Out:
# 15054.0 -10707.75

# %%
data1.loc[data1["Previous_Payment_April"]>15054.0,"Previous_Payment_April"]=15054.0

# %%
sns.distplot(data1.Previous_Payment_April)
# Out:
# <AxesSubplot:xlabel='Previous_Payment_April', ylabel='Density'>

# %%
data1.Previous_Payment_April.hist()
# Out:
# <AxesSubplot:>

# %%
data1.skew()
# Out:
# Credit_Amount              0.440916
# Gender                    -0.424183
# Academic_Qualification     1.017944
# Marital                   -0.018742
# Age_Years                  0.732246
# Repayment_Status_Jan       2.485379
# Repayment_Status_Feb       2.488460
# Repayment_Status_March     2.684191
# Repayment_Status_April     3.213051
# Repayment_Status_May       3.589727
# Repayment_Status_June      3.495517
# Jan_Bill_Amount            1.527639
# Feb_Bill_Amount            1.632576
# March_Bill_Amount          1.626987
# April_Bill_Amount          1.669499
# May_Bill_Amount            1.749921
# June_Bill_Amount           1.749088
# Previous_Payment_Jan       1.878646
# Previous_Payment_Feb       1.741080
# Previous_Payment_March     1.949059
# Previous_Payment_April     1.744791
# Previous_Payment_May      12.231259
# Previous_Payment_June     10.640727
# Default_Payment            1.343504
# dtype: float64

# %%
sns.boxplot(data=data1,y="Previous_Payment_May")
# Out:
# <AxesSubplot:ylabel='Previous_Payment_May'>

# %%
sns.distplot(data1.Previous_Payment_May)
# Out:
# <AxesSubplot:xlabel='Previous_Payment_May', ylabel='Density'>

# %%
data1.Previous_Payment_May.hist()
# Out:
# <AxesSubplot:>

# %%
data1.Previous_Payment_May.describe()
# Out:
# count     30000.00000
# mean       5261.19120
# std       16989.50685
# min           0.00000
# 25%         310.00000
# 50%        1539.00000
# 75%        5000.00000
# max      536539.00000
# Name: Previous_Payment_May, dtype: float64

# %%
IQR13=data1.Previous_Payment_May.quantile(0.75)-data1.Previous_Payment_May.quantile(0.25)
IQR13
# Out:
# 4690.0

# %%
ub13=data1.Previous_Payment_May.quantile(0.75)+3*IQR13
lb13=data1.Previous_Payment_May.quantile(0.25)-3*IQR13
print(ub13,lb13)
# Out:
# 19070.0 -13760.0

# %%
data1.loc[data1["Previous_Payment_May"]>19070.0,"Previous_Payment_May"]=19070.0

# %%
sns.distplot(data1.Previous_Payment_May)
# Out:
# <AxesSubplot:xlabel='Previous_Payment_May', ylabel='Density'>

# %%
data1.Previous_Payment_May.hist()
# Out:
# <AxesSubplot:>

# %%
data1.skew()
# Out:
# Credit_Amount              0.440916
# Gender                    -0.424183
# Academic_Qualification     1.017944
# Marital                   -0.018742
# Age_Years                  0.732246
# Repayment_Status_Jan       2.485379
# Repayment_Status_Feb       2.488460
# Repayment_Status_March     2.684191
# Repayment_Status_April     3.213051
# Repayment_Status_May       3.589727
# Repayment_Status_June      3.495517
# Jan_Bill_Amount            1.527639
# Feb_Bill_Amount            1.632576
# March_Bill_Amount          1.626987
# April_Bill_Amount          1.669499
# May_Bill_Amount            1.749921
# June_Bill_Amount           1.749088
# Previous_Payment_Jan       1.878646
# Previous_Payment_Feb       1.741080
# Previous_Payment_March     1.949059
# Previous_Payment_April     1.744791
# Previous_Payment_May       2.049777
# Previous_Payment_June     10.640727
# Default_Payment            1.343504
# dtype: float64

# %%
sns.boxplot(data=data1,y="Previous_Payment_June")
# Out:
# <AxesSubplot:ylabel='Previous_Payment_June'>

# %%
sns.distplot(data1.Previous_Payment_June)
# Out:
# <AxesSubplot:xlabel='Previous_Payment_June', ylabel='Density'>

# %%
data1.Previous_Payment_June.hist()
# Out:
# <AxesSubplot:>

# %%
data1.Previous_Payment_June.describe()
# Out:
# count     30000.000000
# mean       5215.502567
# std       17777.465775
# min           0.000000
# 25%         117.750000
# 50%        1500.000000
# 75%        4000.000000
# max      528666.000000
# Name: Previous_Payment_June, dtype: float64

# %%
IQR14=data1.Previous_Payment_June.quantile(0.75)-data1.Previous_Payment_June.quantile(0.25)
IQR14
# Out:
# 3882.25

# %%
ub14=data1.Previous_Payment_June.quantile(0.75)+3*IQR14
lb14=data1.Previous_Payment_June.quantile(0.25)-3*IQR14
print(ub14,lb14)
# Out:
# 15646.75 -11529.0

# %%
data1.loc[data1["Previous_Payment_June"]>15646.75,"Previous_Payment_June"]=15646.75

# %%
sns.distplot(data1.Previous_Payment_June)
# Out:
# <AxesSubplot:xlabel='Previous_Payment_June', ylabel='Density'>

# %%
data1.Previous_Payment_June.hist()
# Out:
# <AxesSubplot:>

# %%
data1.skew()
# Out:
# Credit_Amount             0.440916
# Gender                   -0.424183
# Academic_Qualification    1.017944
# Marital                  -0.018742
# Age_Years                 0.732246
# Repayment_Status_Jan      2.485379
# Repayment_Status_Feb      2.488460
# Repayment_Status_March    2.684191
# Repayment_Status_April    3.213051
# Repayment_Status_May      3.589727
# Repayment_Status_June     3.495517
# Jan_Bill_Amount           1.527639
# Feb_Bill_Amount           1.632576
# March_Bill_Amount         1.626987
# April_Bill_Amount         1.669499
# May_Bill_Amount           1.749921
# June_Bill_Amount          1.749088
# Previous_Payment_Jan      1.878646
# Previous_Payment_Feb      1.741080
# Previous_Payment_March    1.949059
# Previous_Payment_April    1.744791
# Previous_Payment_May      2.049777
# Previous_Payment_June     1.842595
# Default_Payment           1.343504
# dtype: float64

# %% [markdown]
# # Skewness Treatment

# %%
#data1['Credit_Amount']=np.sqrt(data1['Credit_Amount'])

# %%
#data1.Credit_Amount.skew()

# %%
sns.distplot(data1.Credit_Amount)
# Out:
# <AxesSubplot:xlabel='Credit_Amount', ylabel='Density'>

# %%
#data1['Credit_Amount']=np.cbrt(data1['Credit_Amount'])

# %%
#data1.Credit_Amount.skew()

# %%
sns.distplot(data1.Credit_Amount)
# Out:
# <AxesSubplot:xlabel='Credit_Amount', ylabel='Density'>

# %%
#data1['Credit_Amount']=np.log(data1['Credit_Amount'])

# %%
#data1.Credit_Amount.skew()

# %%
sns.distplot(data1.Credit_Amount)
# Out:
# <AxesSubplot:xlabel='Credit_Amount', ylabel='Density'>

# %%
#data1['Age_Years']=np.sqrt(data1['Age_Years'])

# %%
#data1.Age_Years.skew()

# %%
sns.distplot(data1.Credit_Amount)
# Out:
# <AxesSubplot:xlabel='Credit_Amount', ylabel='Density'>

# %%
#data1['Age_Years']=np.cbrt(data1['Age_Years'])

# %%
#data1.Age_Years.skew()

# %%
sns.distplot(data1.Credit_Amount)
# Out:
# <AxesSubplot:xlabel='Credit_Amount', ylabel='Density'>

# %%
data1['Age_Years']=np.log(data1['Age_Years'])

# %%
data1.Age_Years.skew()
# Out:
# 0.2432331618785198

# %%
sns.distplot(data1.Age_Years)
# Out:
# <AxesSubplot:xlabel='Age_Years', ylabel='Density'>

# %%
#data1['Jan_Bill_Amount']=np.sqrt(data1['Jan_Bill_Amount'])

# %%
#data1.Jan_Bill_Amount.skew()

# %%
sns.distplot(data1.Jan_Bill_Amount)
# Out:
# <AxesSubplot:xlabel='Jan_Bill_Amount', ylabel='Density'>

# %%
#data1['Jan_Bill_Amount']=np.cbrt(data1['Jan_Bill_Amount'])

# %%
#data1.Jan_Bill_Amount.skew()

# %%
sns.distplot(data1.Jan_Bill_Amount)
# Out:
# <AxesSubplot:xlabel='Jan_Bill_Amount', ylabel='Density'>

# %%
data1['Jan_Bill_Amount']=np.log(data1['Jan_Bill_Amount'])

# %%
data1.Jan_Bill_Amount.skew()
# Out:
# nan

# %%
#sns.distplot(data1.Jan_Bill_Amount)

# %%
#data1['Feb_Bill_Amount']=np.sqrt(data1['Feb_Bill_Amount'])

# %%
#data1.Feb_Bill_Amount.skew()

# %%
sns.distplot(data1.Feb_Bill_Amount)
# Out:
# <AxesSubplot:xlabel='Feb_Bill_Amount', ylabel='Density'>

# %%
#data1['Feb_Bill_Amount']=np.cbrt(data1['Feb_Bill_Amount'])

# %%
#data1.Feb_Bill_Amount.skew()

# %%
sns.distplot(data1.Feb_Bill_Amount)
# Out:
# <AxesSubplot:xlabel='Feb_Bill_Amount', ylabel='Density'>

# %%
data1['Feb_Bill_Amount']=np.log(data1['Feb_Bill_Amount'])

# %%
data1.Feb_Bill_Amount.skew()
# Out:
# nan

# %%
#sns.distplot(data1.Feb_Bill_Amount)

# %%
#data1['March_Bill_Amount']=np.sqrt(data1['March_Bill_Amount'])

# %%
#data1.March_Bill_Amount.skew()

# %%
sns.distplot(data1.March_Bill_Amount)
# Out:
# <AxesSubplot:xlabel='March_Bill_Amount', ylabel='Density'>

# %%
#data1['March_Bill_Amount']=np.cbrt(data1['March_Bill_Amount'])

# %%
#data1.March_Bill_Amount.skew()

# %%
sns.distplot(data1.March_Bill_Amount)
# Out:
# <AxesSubplot:xlabel='March_Bill_Amount', ylabel='Density'>

# %%
data1['March_Bill_Amount']=np.log(data1['March_Bill_Amount'])

# %%
data1.March_Bill_Amount.skew()
# Out:
# nan

# %%
#sns.distplot(data1.March_Bill_Amount)

# %%
#data1['April_Bill_Amount']=np.sqrt(data1['April_Bill_Amount'])

# %%
#data1.April_Bill_Amount.skew()

# %%
sns.distplot(data1.April_Bill_Amount)
# Out:
# <AxesSubplot:xlabel='April_Bill_Amount', ylabel='Density'>

# %%
#data1['April_Bill_Amount']=np.cbrt(data1['April_Bill_Amount'])

# %%
#data1.April_Bill_Amount.skew()

# %%
sns.distplot(data1.April_Bill_Amount)
# Out:
# <AxesSubplot:xlabel='April_Bill_Amount', ylabel='Density'>

# %%
data1['April_Bill_Amount']=np.log(data1['April_Bill_Amount'])

# %%
data1.April_Bill_Amount.skew()
# Out:
# nan

# %%
#sns.distplot(data1.April_Bill_Amount)

# %%
#data1['May_Bill_Amount']=np.sqrt(data1['May_Bill_Amount'])

# %%
#data1.May_Bill_Amount.skew()

# %%
sns.distplot(data1.May_Bill_Amount)
# Out:
# <AxesSubplot:xlabel='May_Bill_Amount', ylabel='Density'>

# %%
#data1['May_Bill_Amount']=np.cbrt(data1['May_Bill_Amount'])

# %%
#data1.May_Bill_Amount.skew()

# %%
sns.distplot(data1.May_Bill_Amount)
# Out:
# <AxesSubplot:xlabel='May_Bill_Amount', ylabel='Density'>

# %%
data1['May_Bill_Amount']=np.log(data1['May_Bill_Amount'])

# %%
data1.May_Bill_Amount.skew()
# Out:
# nan

# %%
#sns.distplot(data1.May_Bill_Amount)

# %%
#data1['June_Bill_Amount']=np.sqrt(data1['June_Bill_Amount'])

# %%
#data1.June_Bill_Amount.skew()

# %%
sns.distplot(data1.June_Bill_Amount)
# Out:
# <AxesSubplot:xlabel='June_Bill_Amount', ylabel='Density'>

# %%
#data1['June_Bill_Amount']=np.cbrt(data1['June_Bill_Amount'])

# %%
#data1.June_Bill_Amount.skew()

# %%
sns.distplot(data1.June_Bill_Amount)
# Out:
# <AxesSubplot:xlabel='June_Bill_Amount', ylabel='Density'>

# %%
data1['June_Bill_Amount']=np.log(data1['June_Bill_Amount'])

# %%
data1.June_Bill_Amount.skew()
# Out:
# nan

# %%
#sns.distplot(data1.June_Bill_Amount)

# %%
#data1['Previous_Payment_Jan']=np.sqrt(data1['Previous_Payment_Jan'])

# %%
#data1.Previous_Payment_Jan.skew()

# %%
sns.distplot(data1.Previous_Payment_Jan)
# Out:
# <AxesSubplot:xlabel='Previous_Payment_Jan', ylabel='Density'>

# %%
#data1['Previous_Payment_Jan']=np.cbrt(data1['Previous_Payment_Jan'])

# %%
#data1.Previous_Payment_Jan.skew()

# %%
sns.distplot(data1.Previous_Payment_Jan)
# Out:
# <AxesSubplot:xlabel='Previous_Payment_Jan', ylabel='Density'>

# %%
data1['Previous_Payment_Jan']=np.log(data1['Previous_Payment_Jan'])

# %%
data1.Previous_Payment_Jan.skew()
# Out:
# nan

# %%
#sns.distplot(data1.Previous_Payment_Jan)

# %%
#data1['Previous_Payment_Feb']=np.sqrt(data1['Previous_Payment_Feb'])

# %%
#data1.Previous_Payment_Feb.skew()

# %%
sns.distplot(data1.Previous_Payment_Feb)
# Out:
# <AxesSubplot:xlabel='Previous_Payment_Feb', ylabel='Density'>

# %%
#data1['Previous_Payment_Feb']=np.cbrt(data1['Previous_Payment_Feb'])

# %%
#data1.Previous_Payment_Feb.skew()

# %%
sns.distplot(data1.Previous_Payment_Feb)
# Out:
# <AxesSubplot:xlabel='Previous_Payment_Feb', ylabel='Density'>

# %%
data1['Previous_Payment_Feb']=np.log(data1['Previous_Payment_Feb'])

# %%
data1.Previous_Payment_Feb.skew()
# Out:
# nan

# %%
#sns.distplot(data1.Previous_Payment_Feb)

# %%
#data1['Previous_Payment_March']=np.sqrt(data1['Previous_Payment_March'])

# %%
#data1.Previous_Payment_March.skew()

# %%
sns.distplot(data1.Previous_Payment_March)
# Out:
# <AxesSubplot:xlabel='Previous_Payment_March', ylabel='Density'>

# %%
#data1['Previous_Payment_March']=np.cbrt(data1['Previous_Payment_March'])

# %%
#data1.Previous_Payment_March.skew()

# %%
sns.distplot(data1.Previous_Payment_March)
# Out:
# <AxesSubplot:xlabel='Previous_Payment_March', ylabel='Density'>

# %%
data1['Previous_Payment_March']=np.log(data1['Previous_Payment_March'])

# %%
data1.Previous_Payment_March.skew()
# Out:
# nan

# %%
#sns.distplot(data1.Previous_Payment_March)

# %%
#data1['Previous_Payment_April']=np.sqrt(data1['Previous_Payment_April'])

# %%
#data1.Previous_Payment_April.skew()

# %%
sns.distplot(data1.Previous_Payment_April)
# Out:
# <AxesSubplot:xlabel='Previous_Payment_April', ylabel='Density'>

# %%
#data1['Previous_Payment_April']=np.cbrt(data1['Previous_Payment_April'])

# %%
#data1.Previous_Payment_April.skew()

# %%
sns.distplot(data1.Previous_Payment_April)
# Out:
# <AxesSubplot:xlabel='Previous_Payment_April', ylabel='Density'>

# %%
data1['Previous_Payment_April']=np.log(data1['Previous_Payment_April'])

# %%
data1.Previous_Payment_April.skew()
# Out:
# nan

# %%
#sns.distplot(data1.Previous_Payment_April)

# %%
#data1['Previous_Payment_May']=np.sqrt(data1['Previous_Payment_May'])

# %%
#data1.Previous_Payment_May.skew()

# %%
sns.distplot(data1.Previous_Payment_May)
# Out:
# <AxesSubplot:xlabel='Previous_Payment_May', ylabel='Density'>

# %%
#data1['Previous_Payment_May']=np.cbrt(data1['Previous_Payment_May'])

# %%
#data1.Previous_Payment_May.skew()

# %%
sns.distplot(data1.Previous_Payment_May)
# Out:
# <AxesSubplot:xlabel='Previous_Payment_May', ylabel='Density'>

# %%
data1['Previous_Payment_May']=np.log(data1['Previous_Payment_May'])

# %%
data1.Previous_Payment_May.skew()
# Out:
# nan

# %%
#sns.distplot(data1.Previous_Payment_May)

# %%
#data1['Previous_Payment_June']=np.sqrt(data1['Previous_Payment_June'])

# %%
#data1.Previous_Payment_June.skew()

# %%
sns.distplot(data1.Previous_Payment_June)
# Out:
# <AxesSubplot:xlabel='Previous_Payment_June', ylabel='Density'>

# %%
#data1['Previous_Payment_June']=np.cbrt(data1['Previous_Payment_June'])

# %%
#data1.Previous_Payment_June.skew()

# %%
sns.distplot(data1.Previous_Payment_June)
# Out:
# <AxesSubplot:xlabel='Previous_Payment_June', ylabel='Density'>

# %%
data1['Previous_Payment_June']=np.log(data1['Previous_Payment_June'])

# %%
data1.Previous_Payment_June.skew()
# Out:
# nan

# %%
#sns.distplot(data1.Previous_Payment_June)
